# %% [markdown]
# ## Setting Up

# %%
import os

MODEL = os.getenv("OPENAI_MODEL")

# %%
from agents import Agent, Runner

agent = Agent(
    name="Assistant",
    instructions="You're a helpful assistant",
    model=MODEL
)

# %% [markdown]
# ## Agent Runner
#
# Running the Agent Asynchronously
#
# `Runner.run()` runs the agent in async mode

# %%
result = await Runner.run(
    agent,
    "Tell me a short story"
)

result.final_output
# Out:
# 'Once upon a time, in a small village nestled between rolling hills, there lived a young girl named Lila. Lila was known for her insatiable curiosity and love for exploring the nearby woods. Each day, she would venture deeper into the forest, collecting beautiful stones and observing the vibrant wildlife.\n\nOne sunny afternoon, as she wandered off the beaten path, Lila stumbled upon a hidden glade. In the center of the glade stood an ancient oak tree, its trunk wide and gnarled, with leaves that shimmered like emeralds in the sunlight. To her astonishment, she noticed a small, iridescent door at the base of the tree.\n\nWith her heart racing, Lila approached the door and, on a whim, knocked lightly. To her surprise, the door creaked open, revealing a tiny, shimmering world inside. A small voice greeted her, “Welcome, traveler! I’m Elyan, the guardian of this enchanted grove.”\n\nElyan explained that the glade was a sanctuary for all the magical creatures of the forest. However, it needed a protector, someone with a pure heart and a deep love for nature. Lila felt a warm glow in her chest as she accepted the responsibility.\n\nFrom that day forward, Lila became the guardian of the glade. She spent her days caring for the plants, tending to the creatures, and learning the secrets of the forest. In return, the glade gifted her with wisdom and the ability to understand the language of animals.\n\nYears later, when Lila grew up, she became a bridge between the village and the enchanted woods, teaching others the value of harmony with nature. And so, the bond between the village and the magical forest thrived, all thanks to a curious girl who had the courage to explore a hidden world.'

# %% [markdown]
# ### Async Streaming Mode
#
# Start by creating a response using `Runner.run_streamed(...)`  \
# Then iterate over it asynchronously

# %%
response = Runner.run_streamed(
    agent,
    "Tell me a short story"
)

async for event in response.stream_events():
    print(event)
# Out:
# AgentUpdatedStreamEvent(new_agent=Agent(name='Assistant', instructions="You're a helpful assistant", handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=False, truncation=None, max_tokens=None), tools=[], mcp_servers=[], input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), type='agent_updated_stream_event')
# RawResponsesStreamEvent(data=ResponseCreatedEvent(response=Response(id='resp_67f0012024948191a6edc3040f1fb4cc0f03f95e296eb698', created_at=1743782176.0, error=None, incomplete_details=None, instructions="You're a helpful assistant", metadata={}, model='gpt-4o-mini-2024-07-18', object='response', output=[], parallel_tool_calls=False, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, max_output_tokens=None, previous_response_id=None, reasoning=Reasoning(effort=None, generate_summary=None), status='in_progress', text=ResponseTextConfig(format=ResponseFormatText(type='text')), truncation='disabled', usage=None, user=None, store=True), type='response.created'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseInProgressEvent(response=Response(id='resp_67f0012024948191a6edc3040f1fb4cc0f03f95e296eb698', created_at=1743782176.0, error=None, incomplete_details=None, instructions="You're a helpful assistant", metadata={}, model='gpt-4o-mini-2024-07-18', object='response', output=[], parallel_tool_calls=False, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, max_output_tokens=None, previous_response_id=None, reasoning=Reasoning(effort=None, generate_summary=None), status='in_progress', text=ResponseTextConfig(format=ResponseFormatText(type='text')), truncation='disabled', usage=None, user=None, store=True), type='response.in_progress'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseOutputItemAddedEvent(item=ResponseOutputMessage(id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', content=[], role='assistant', status='in_progress', type='message'), output_index=0, type='response.output_item.added'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseContentPartAddedEvent(content_index=0, item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, part=ResponseOutputText(annotations=[], text='', type='output_text'), type='response.content_part.added'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='Once', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' upon', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' time', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' in', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' small', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' village', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' nestled', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' between', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' rolling', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' hills', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' there', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' lived', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' curious', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' little', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' girl', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' named', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' L', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='ila', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='.', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' She', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' had', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' wild', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' imagination', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' and', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' spent', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' her', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' days', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' exploring', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' me', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='adows', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' and', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' forests', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' nearby', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' always', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' searching', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' for', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' adventure', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='.\n\n', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='One', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' sunny', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' afternoon', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' while', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' wandering', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' deeper', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' into', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' woods', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' than', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' she', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' ever', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' had', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' before', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' L', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='ila', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' stumbled', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' upon', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' hidden', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' gl', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='ade', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='.', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' In', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' center', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' of', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' gl', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='ade', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' stood', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' an', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' ancient', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' oak', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' tree', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' its', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' branches', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' stretching', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' wide', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' and', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' its', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' trunk', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' g', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='nar', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='led', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' with', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' age', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='.', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' To', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' her', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' aston', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='ishment', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' she', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' noticed', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' that', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' tree', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' was', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' adorned', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' with', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' tiny', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' colorful', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' doors', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' of', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' all', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' shapes', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' and', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' sizes', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='.\n\n', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='Intr', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='ig', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='ued', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' L', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='ila', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' approached', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' tree', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' and', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' gently', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' touched', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' one', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' of', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' doors', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='.', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' To', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' her', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' surprise', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' it', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' swung', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' open', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' revealing', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' bustling', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' world', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' within', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' oak', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='.', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' Little', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' creatures', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' with', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' wings', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' that', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' spark', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='led', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' like', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' morning', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' dew', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' dart', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='ed', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' in', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' and', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' out', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' laughing', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' and', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' singing', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='.', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' They', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' were', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' Guardians', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' of', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' the', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' Forest', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' tasked', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' with', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' protecting', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' nature', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='’s', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' secrets', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='.\n\n', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='“', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='Welcome', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=',', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' L', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='ila', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='!”', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' chim', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='ed', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' a', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' tiny', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' fairy', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# ...
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' name', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='.', item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDoneEvent(content_index=0, item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, text='Once upon a time in a small village nestled between rolling hills, there lived a curious little girl named Lila. She had a wild imagination and spent her days exploring the meadows and forests nearby, always searching for adventure.\n\nOne sunny afternoon, while wandering deeper into the woods than she ever had before, Lila stumbled upon a hidden glade. In the center of the glade stood an ancient oak tree, its branches stretching wide and its trunk gnarled with age. To her astonishment, she noticed that the tree was adorned with tiny, colorful doors of all shapes and sizes.\n\nIntrigued, Lila approached the tree and gently touched one of the doors. To her surprise, it swung open, revealing a bustling world within the oak. Little creatures, with wings that sparkled like morning dew, darted in and out, laughing and singing. They were the Guardians of the Forest, tasked with protecting nature’s secrets.\n\n“Welcome, Lila!” chimed a tiny fairy with shimmering blue wings. “We’ve been waiting for someone kind-hearted like you. Will you help us?”\n\nThe fairies explained that a dark cloud was looming over their home, threatening to steal the joy from the forest. With courage and determination, Lila agreed to help. She joined the fairies on a quest to gather the lost colors of the forest, hidden away by the darkness.\n\nTogether, they danced through the trees, laughed under waterfalls, and shared stories with the animals. With each adventure, they reclaimed a piece of the vibrant world that had been taken. As they worked, Lila felt the magic of the forest embracing her, filling her with hope and joy.\n\nFinally, after what felt like both an eternity and a fleeting moment, they stood together, hand in hand, facing the dark cloud. With a burst of laughter and song, they unleashed the colors they had reclaimed. The dark cloud melted away, revealing a radiant sun that lit up the forest in hues of green, gold, and violet.\n\nThe forest flourished, more beautiful than ever, and the Guardians celebrated their victory. Lila bid farewell to her newfound friends, promising to return. As she walked back home, she felt a warmth in her heart, knowing that magic was real, and adventure always awaited those who dared to seek it.\n\nFrom that day on, the village thrived with more life and laughter, all thanks to the brave little girl who ventured into the woods and believed in the power of friendship and courage. And every time the wind whispered through the trees, Lila knew the fairies were singing her name.', type='response.output_text.done'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseContentPartDoneEvent(content_index=0, item_id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', output_index=0, part=ResponseOutputText(annotations=[], text='Once upon a time in a small village nestled between rolling hills, there lived a curious little girl named Lila. She had a wild imagination and spent her days exploring the meadows and forests nearby, always searching for adventure.\n\nOne sunny afternoon, while wandering deeper into the woods than she ever had before, Lila stumbled upon a hidden glade. In the center of the glade stood an ancient oak tree, its branches stretching wide and its trunk gnarled with age. To her astonishment, she noticed that the tree was adorned with tiny, colorful doors of all shapes and sizes.\n\nIntrigued, Lila approached the tree and gently touched one of the doors. To her surprise, it swung open, revealing a bustling world within the oak. Little creatures, with wings that sparkled like morning dew, darted in and out, laughing and singing. They were the Guardians of the Forest, tasked with protecting nature’s secrets.\n\n“Welcome, Lila!” chimed a tiny fairy with shimmering blue wings. “We’ve been waiting for someone kind-hearted like you. Will you help us?”\n\nThe fairies explained that a dark cloud was looming over their home, threatening to steal the joy from the forest. With courage and determination, Lila agreed to help. She joined the fairies on a quest to gather the lost colors of the forest, hidden away by the darkness.\n\nTogether, they danced through the trees, laughed under waterfalls, and shared stories with the animals. With each adventure, they reclaimed a piece of the vibrant world that had been taken. As they worked, Lila felt the magic of the forest embracing her, filling her with hope and joy.\n\nFinally, after what felt like both an eternity and a fleeting moment, they stood together, hand in hand, facing the dark cloud. With a burst of laughter and song, they unleashed the colors they had reclaimed. The dark cloud melted away, revealing a radiant sun that lit up the forest in hues of green, gold, and violet.\n\nThe forest flourished, more beautiful than ever, and the Guardians celebrated their victory. Lila bid farewell to her newfound friends, promising to return. As she walked back home, she felt a warmth in her heart, knowing that magic was real, and adventure always awaited those who dared to seek it.\n\nFrom that day on, the village thrived with more life and laughter, all thanks to the brave little girl who ventured into the woods and believed in the power of friendship and courage. And every time the wind whispered through the trees, Lila knew the fairies were singing her name.', type='output_text'), type='response.content_part.done'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseOutputItemDoneEvent(item=ResponseOutputMessage(id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', content=[ResponseOutputText(annotations=[], text='Once upon a time in a small village nestled between rolling hills, there lived a curious little girl named Lila. She had a wild imagination and spent her days exploring the meadows and forests nearby, always searching for adventure.\n\nOne sunny afternoon, while wandering deeper into the woods than she ever had before, Lila stumbled upon a hidden glade. In the center of the glade stood an ancient oak tree, its branches stretching wide and its trunk gnarled with age. To her astonishment, she noticed that the tree was adorned with tiny, colorful doors of all shapes and sizes.\n\nIntrigued, Lila approached the tree and gently touched one of the doors. To her surprise, it swung open, revealing a bustling world within the oak. Little creatures, with wings that sparkled like morning dew, darted in and out, laughing and singing. They were the Guardians of the Forest, tasked with protecting nature’s secrets.\n\n“Welcome, Lila!” chimed a tiny fairy with shimmering blue wings. “We’ve been waiting for someone kind-hearted like you. Will you help us?”\n\nThe fairies explained that a dark cloud was looming over their home, threatening to steal the joy from the forest. With courage and determination, Lila agreed to help. She joined the fairies on a quest to gather the lost colors of the forest, hidden away by the darkness.\n\nTogether, they danced through the trees, laughed under waterfalls, and shared stories with the animals. With each adventure, they reclaimed a piece of the vibrant world that had been taken. As they worked, Lila felt the magic of the forest embracing her, filling her with hope and joy.\n\nFinally, after what felt like both an eternity and a fleeting moment, they stood together, hand in hand, facing the dark cloud. With a burst of laughter and song, they unleashed the colors they had reclaimed. The dark cloud melted away, revealing a radiant sun that lit up the forest in hues of green, gold, and violet.\n\nThe forest flourished, more beautiful than ever, and the Guardians celebrated their victory. Lila bid farewell to her newfound friends, promising to return. As she walked back home, she felt a warmth in her heart, knowing that magic was real, and adventure always awaited those who dared to seek it.\n\nFrom that day on, the village thrived with more life and laughter, all thanks to the brave little girl who ventured into the woods and believed in the power of friendship and courage. And every time the wind whispered through the trees, Lila knew the fairies were singing her name.', type='output_text')], role='assistant', status='completed', type='message'), output_index=0, type='response.output_item.done'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseCompletedEvent(response=Response(id='resp_67f0012024948191a6edc3040f1fb4cc0f03f95e296eb698', created_at=1743782176.0, error=None, incomplete_details=None, instructions="You're a helpful assistant", metadata={}, model='gpt-4o-mini-2024-07-18', object='response', output=[ResponseOutputMessage(id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', content=[ResponseOutputText(annotations=[], text='Once upon a time in a small village nestled between rolling hills, there lived a curious little girl named Lila. She had a wild imagination and spent her days exploring the meadows and forests nearby, always searching for adventure.\n\nOne sunny afternoon, while wandering deeper into the woods than she ever had before, Lila stumbled upon a hidden glade. In the center of the glade stood an ancient oak tree, its branches stretching wide and its trunk gnarled with age. To her astonishment, she noticed that the tree was adorned with tiny, colorful doors of all shapes and sizes.\n\nIntrigued, Lila approached the tree and gently touched one of the doors. To her surprise, it swung open, revealing a bustling world within the oak. Little creatures, with wings that sparkled like morning dew, darted in and out, laughing and singing. They were the Guardians of the Forest, tasked with protecting nature’s secrets.\n\n“Welcome, Lila!” chimed a tiny fairy with shimmering blue wings. “We’ve been waiting for someone kind-hearted like you. Will you help us?”\n\nThe fairies explained that a dark cloud was looming over their home, threatening to steal the joy from the forest. With courage and determination, Lila agreed to help. She joined the fairies on a quest to gather the lost colors of the forest, hidden away by the darkness.\n\nTogether, they danced through the trees, laughed under waterfalls, and shared stories with the animals. With each adventure, they reclaimed a piece of the vibrant world that had been taken. As they worked, Lila felt the magic of the forest embracing her, filling her with hope and joy.\n\nFinally, after what felt like both an eternity and a fleeting moment, they stood together, hand in hand, facing the dark cloud. With a burst of laughter and song, they unleashed the colors they had reclaimed. The dark cloud melted away, revealing a radiant sun that lit up the forest in hues of green, gold, and violet.\n\nThe forest flourished, more beautiful than ever, and the Guardians celebrated their victory. Lila bid farewell to her newfound friends, promising to return. As she walked back home, she felt a warmth in her heart, knowing that magic was real, and adventure always awaited those who dared to seek it.\n\nFrom that day on, the village thrived with more life and laughter, all thanks to the brave little girl who ventured into the woods and believed in the power of friendship and courage. And every time the wind whispered through the trees, Lila knew the fairies were singing her name.', type='output_text')], role='assistant', status='completed', type='message')], parallel_tool_calls=False, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, max_output_tokens=None, previous_response_id=None, reasoning=Reasoning(effort=None, generate_summary=None), status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text')), truncation='disabled', usage=ResponseUsage(input_tokens=20, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=525, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=545), user=None, store=True), type='response.completed'), type='raw_response_event')
# RunItemStreamEvent(name='message_output_created', item=MessageOutputItem(agent=Agent(name='Assistant', instructions="You're a helpful assistant", handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=False, truncation=None, max_tokens=None), tools=[], mcp_servers=[], input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseOutputMessage(id='msg_67f0012079c081919c2d84456cc005c60f03f95e296eb698', content=[ResponseOutputText(annotations=[], text='Once upon a time in a small village nestled between rolling hills, there lived a curious little girl named Lila. She had a wild imagination and spent her days exploring the meadows and forests nearby, always searching for adventure.\n\nOne sunny afternoon, while wandering deeper into the woods than she ever had before, Lila stumbled upon a hidden glade. In the center of the glade stood an ancient oak tree, its branches stretching wide and its trunk gnarled with age. To her astonishment, she noticed that the tree was adorned with tiny, colorful doors of all shapes and sizes.\n\nIntrigued, Lila approached the tree and gently touched one of the doors. To her surprise, it swung open, revealing a bustling world within the oak. Little creatures, with wings that sparkled like morning dew, darted in and out, laughing and singing. They were the Guardians of the Forest, tasked with protecting nature’s secrets.\n\n“Welcome, Lila!” chimed a tiny fairy with shimmering blue wings. “We’ve been waiting for someone kind-hearted like you. Will you help us?”\n\nThe fairies explained that a dark cloud was looming over their home, threatening to steal the joy from the forest. With courage and determination, Lila agreed to help. She joined the fairies on a quest to gather the lost colors of the forest, hidden away by the darkness.\n\nTogether, they danced through the trees, laughed under waterfalls, and shared stories with the animals. With each adventure, they reclaimed a piece of the vibrant world that had been taken. As they worked, Lila felt the magic of the forest embracing her, filling her with hope and joy.\n\nFinally, after what felt like both an eternity and a fleeting moment, they stood together, hand in hand, facing the dark cloud. With a burst of laughter and song, they unleashed the colors they had reclaimed. The dark cloud melted away, revealing a radiant sun that lit up the forest in hues of green, gold, and violet.\n\nThe forest flourished, more beautiful than ever, and the Guardians celebrated their victory. Lila bid farewell to her newfound friends, promising to return. As she walked back home, she felt a warmth in her heart, knowing that magic was real, and adventure always awaited those who dared to seek it.\n\nFrom that day on, the village thrived with more life and laughter, all thanks to the brave little girl who ventured into the woods and believed in the power of friendship and courage. And every time the wind whispered through the trees, Lila knew the fairies were singing her name.', type='output_text')], role='assistant', status='completed', type='message'), type='message_output_item'), type='run_item_stream_event')

# %% [markdown]
# ## Events
#
# The streaming response returns **Events**. This helps us filter the output to extract relevant information.
#
# There are several events:
# * RawEvent: Token output
# * AgentUpdated: Agent creation
# * StreamEvent: A message being completed
# *

# %%
from openai.types.responses import ResponseTextDeltaEvent

response = Runner.run_streamed(
    agent,
    "Tell me a short story"
)

async for event in response.stream_events():
     if event.type == "raw_response_event" and \
         isinstance(event.data, ResponseTextDeltaEvent):
             print(event.data.delta, end="", flush=True)
# Out:
# Once upon a time in a small village nestled between lush green hills, there lived a young girl named Lila. Lila had a curious mind and an adventurous spirit, always exploring the meadows and woods surrounding her home.
#
# One sunny afternoon, while wandering deeper into the forest than usual, she stumbled upon an old, gnarled tree with a hollow trunk. Peering inside, she discovered a shimmering key resting on a bed of moss. Intrigued, Lila took the key and decided to find what it might unlock.
#
# After searching for days, she noticed a hidden door in the base of a nearby hill, covered in vines and seemingly forgotten. With a heart racing with excitement, she inserted the key into the lock. To her amazement, the door creaked open, revealing a magical world full of vibrant creatures and fantastical landscapes.
#
# In this enchanted realm, Lila befriended talking animals, danced with fairies, and even learned the art of cloud-painting from a wise old owl. Each adventure sparked her imagination and filled her with joy.
#
# But as the sun began to set, she felt a tug at her heart, reminding her of her home. Knowing she had to return, Lila promised her new friends she would come back. With the key clutched tightly in her hand, she stepped through the door and back into her world.
#
# From that day on, Lila visited the magical realm whenever she could, carrying stories of her adventures to share with her friends back home. She learned that while magic exists in faraway places, it can also be found in the wonders of her everyday life. And so, Lila grew up with the heart of an explorer, forever cherishing the balance between reality and imagination.

# %% [markdown]
# ## Tools

# %%
from agents import function_tool

@function_tool
def multiply(x: int, y: int) -> int:
    """Multiply 2 numbers to provide the product"""
    return x*y

# %%
agent = Agent(
    name="Assistant",
    instructions="""
        You're a helpful assistant who uses,
        provided tools to help whenever possible.,
        Do not rely on your own knowledge too much,
        instead use the tools to answer queries.
    """,
    model=MODEL,
    tools=[multiply]
)

# %%
response = Runner.run_streamed(
    agent,
    "What is the product of 4 and 100 ?"
)

async for event in response.stream_events():
    print(event)
# Out:
# AgentUpdatedStreamEvent(new_agent=Agent(name='Assistant', instructions="\n        You're a helpful assistant who uses,\n        provided tools to help whenever possible.,\n        Do not rely on your own knowledge too much,\n        instead use the tools to answer queries.\n    ", handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=False, truncation=None, max_tokens=None), tools=[FunctionTool(name='multiply', description='Multiply 2 numbers to provide the product', params_json_schema={'properties': {'x': {'title': 'X', 'type': 'integer'}, 'y': {'title': 'Y', 'type': 'integer'}}, 'required': ['x', 'y'], 'title': 'multiply_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x71e8678edbd0>, strict_json_schema=True)], mcp_servers=[], input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), type='agent_updated_stream_event')
# RawResponsesStreamEvent(data=ResponseCreatedEvent(response=Response(id='resp_67f001373f588191812ae9320d3a221f033b035ae1f324ea', created_at=1743782199.0, error=None, incomplete_details=None, instructions="\n        You're a helpful assistant who uses,\n        provided tools to help whenever possible.,\n        Do not rely on your own knowledge too much,\n        instead use the tools to answer queries.\n    ", metadata={}, model='gpt-4o-mini-2024-07-18', object='response', output=[], parallel_tool_calls=False, temperature=1.0, tool_choice='auto', tools=[FunctionTool(name='multiply', parameters={'properties': {'x': {'title': 'X', 'type': 'integer'}, 'y': {'title': 'Y', 'type': 'integer'}}, 'required': ['x', 'y'], 'title': 'multiply_args', 'type': 'object', 'additionalProperties': False}, strict=True, type='function', description='Multiply 2 numbers to provide the product')], top_p=1.0, max_output_tokens=None, previous_response_id=None, reasoning=Reasoning(effort=None, generate_summary=None), status='in_progress', text=ResponseTextConfig(format=ResponseFormatText(type='text')), truncation='disabled', usage=None, user=None, store=True), type='response.created'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseInProgressEvent(response=Response(id='resp_67f001373f588191812ae9320d3a221f033b035ae1f324ea', created_at=1743782199.0, error=None, incomplete_details=None, instructions="\n        You're a helpful assistant who uses,\n        provided tools to help whenever possible.,\n        Do not rely on your own knowledge too much,\n        instead use the tools to answer queries.\n    ", metadata={}, model='gpt-4o-mini-2024-07-18', object='response', output=[], parallel_tool_calls=False, temperature=1.0, tool_choice='auto', tools=[FunctionTool(name='multiply', parameters={'properties': {'x': {'title': 'X', 'type': 'integer'}, 'y': {'title': 'Y', 'type': 'integer'}}, 'required': ['x', 'y'], 'title': 'multiply_args', 'type': 'object', 'additionalProperties': False}, strict=True, type='function', description='Multiply 2 numbers to provide the product')], top_p=1.0, max_output_tokens=None, previous_response_id=None, reasoning=Reasoning(effort=None, generate_summary=None), status='in_progress', text=ResponseTextConfig(format=ResponseFormatText(type='text')), truncation='disabled', usage=None, user=None, store=True), type='response.in_progress'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseOutputItemAddedEvent(item=ResponseFunctionToolCall(arguments='', call_id='call_WSPKti7c4PZyPqUMM3K0AhkT', name='multiply', type='function_call', id='fc_67f00137b4b481919a647987be7f28ca033b035ae1f324ea', status='in_progress'), output_index=0, type='response.output_item.added'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseFunctionCallArgumentsDeltaEvent(delta='{"', item_id='fc_67f00137b4b481919a647987be7f28ca033b035ae1f324ea', output_index=0, type='response.function_call_arguments.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseFunctionCallArgumentsDeltaEvent(delta='x', item_id='fc_67f00137b4b481919a647987be7f28ca033b035ae1f324ea', output_index=0, type='response.function_call_arguments.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseFunctionCallArgumentsDeltaEvent(delta='":', item_id='fc_67f00137b4b481919a647987be7f28ca033b035ae1f324ea', output_index=0, type='response.function_call_arguments.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseFunctionCallArgumentsDeltaEvent(delta='4', item_id='fc_67f00137b4b481919a647987be7f28ca033b035ae1f324ea', output_index=0, type='response.function_call_arguments.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseFunctionCallArgumentsDeltaEvent(delta=',"', item_id='fc_67f00137b4b481919a647987be7f28ca033b035ae1f324ea', output_index=0, type='response.function_call_arguments.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseFunctionCallArgumentsDeltaEvent(delta='y', item_id='fc_67f00137b4b481919a647987be7f28ca033b035ae1f324ea', output_index=0, type='response.function_call_arguments.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseFunctionCallArgumentsDeltaEvent(delta='":', item_id='fc_67f00137b4b481919a647987be7f28ca033b035ae1f324ea', output_index=0, type='response.function_call_arguments.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseFunctionCallArgumentsDeltaEvent(delta='100', item_id='fc_67f00137b4b481919a647987be7f28ca033b035ae1f324ea', output_index=0, type='response.function_call_arguments.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseFunctionCallArgumentsDeltaEvent(delta='}', item_id='fc_67f00137b4b481919a647987be7f28ca033b035ae1f324ea', output_index=0, type='response.function_call_arguments.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseFunctionCallArgumentsDoneEvent(arguments='{"x":4,"y":100}', item_id='fc_67f00137b4b481919a647987be7f28ca033b035ae1f324ea', output_index=0, type='response.function_call_arguments.done'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseOutputItemDoneEvent(item=ResponseFunctionToolCall(arguments='{"x":4,"y":100}', call_id='call_WSPKti7c4PZyPqUMM3K0AhkT', name='multiply', type='function_call', id='fc_67f00137b4b481919a647987be7f28ca033b035ae1f324ea', status='completed'), output_index=0, type='response.output_item.done'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseCompletedEvent(response=Response(id='resp_67f001373f588191812ae9320d3a221f033b035ae1f324ea', created_at=1743782199.0, error=None, incomplete_details=None, instructions="\n        You're a helpful assistant who uses,\n        provided tools to help whenever possible.,\n        Do not rely on your own knowledge too much,\n        instead use the tools to answer queries.\n    ", metadata={}, model='gpt-4o-mini-2024-07-18', object='response', output=[ResponseFunctionToolCall(arguments='{"x":4,"y":100}', call_id='call_WSPKti7c4PZyPqUMM3K0AhkT', name='multiply', type='function_call', id='fc_67f00137b4b481919a647987be7f28ca033b035ae1f324ea', status='completed')], parallel_tool_calls=False, temperature=1.0, tool_choice='auto', tools=[FunctionTool(name='multiply', parameters={'properties': {'x': {'title': 'X', 'type': 'integer'}, 'y': {'title': 'Y', 'type': 'integer'}}, 'required': ['x', 'y'], 'title': 'multiply_args', 'type': 'object', 'additionalProperties': False}, strict=True, type='function', description='Multiply 2 numbers to provide the product')], top_p=1.0, max_output_tokens=None, previous_response_id=None, reasoning=Reasoning(effort=None, generate_summary=None), status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text')), truncation='disabled', usage=ResponseUsage(input_tokens=108, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=18, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=126), user=None, store=True), type='response.completed'), type='raw_response_event')
# RunItemStreamEvent(name='tool_called', item=ToolCallItem(agent=Agent(name='Assistant', instructions="\n        You're a helpful assistant who uses,\n        provided tools to help whenever possible.,\n        Do not rely on your own knowledge too much,\n        instead use the tools to answer queries.\n    ", handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=False, truncation=None, max_tokens=None), tools=[FunctionTool(name='multiply', description='Multiply 2 numbers to provide the product', params_json_schema={'properties': {'x': {'title': 'X', 'type': 'integer'}, 'y': {'title': 'Y', 'type': 'integer'}}, 'required': ['x', 'y'], 'title': 'multiply_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x71e8678edbd0>, strict_json_schema=True)], mcp_servers=[], input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseFunctionToolCall(arguments='{"x":4,"y":100}', call_id='call_WSPKti7c4PZyPqUMM3K0AhkT', name='multiply', type='function_call', id='fc_67f00137b4b481919a647987be7f28ca033b035ae1f324ea', status='completed'), type='tool_call_item'), type='run_item_stream_event')
# RunItemStreamEvent(name='tool_output', item=ToolCallOutputItem(agent=Agent(name='Assistant', instructions="\n        You're a helpful assistant who uses,\n        provided tools to help whenever possible.,\n        Do not rely on your own knowledge too much,\n        instead use the tools to answer queries.\n    ", handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=False, truncation=None, max_tokens=None), tools=[FunctionTool(name='multiply', description='Multiply 2 numbers to provide the product', params_json_schema={'properties': {'x': {'title': 'X', 'type': 'integer'}, 'y': {'title': 'Y', 'type': 'integer'}}, 'required': ['x', 'y'], 'title': 'multiply_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x71e8678edbd0>, strict_json_schema=True)], mcp_servers=[], input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item={'call_id': 'call_WSPKti7c4PZyPqUMM3K0AhkT', 'output': '400', 'type': 'function_call_output'}, output=400, type='tool_call_output_item'), type='run_item_stream_event')
# RawResponsesStreamEvent(data=ResponseCreatedEvent(response=Response(id='resp_67f00138248881918da842ac4b343f96033b035ae1f324ea', created_at=1743782200.0, error=None, incomplete_details=None, instructions="\n        You're a helpful assistant who uses,\n        provided tools to help whenever possible.,\n        Do not rely on your own knowledge too much,\n        instead use the tools to answer queries.\n    ", metadata={}, model='gpt-4o-mini-2024-07-18', object='response', output=[], parallel_tool_calls=False, temperature=1.0, tool_choice='auto', tools=[FunctionTool(name='multiply', parameters={'properties': {'x': {'title': 'X', 'type': 'integer'}, 'y': {'title': 'Y', 'type': 'integer'}}, 'required': ['x', 'y'], 'title': 'multiply_args', 'type': 'object', 'additionalProperties': False}, strict=True, type='function', description='Multiply 2 numbers to provide the product')], top_p=1.0, max_output_tokens=None, previous_response_id=None, reasoning=Reasoning(effort=None, generate_summary=None), status='in_progress', text=ResponseTextConfig(format=ResponseFormatText(type='text')), truncation='disabled', usage=None, user=None, store=True), type='response.created'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseInProgressEvent(response=Response(id='resp_67f00138248881918da842ac4b343f96033b035ae1f324ea', created_at=1743782200.0, error=None, incomplete_details=None, instructions="\n        You're a helpful assistant who uses,\n        provided tools to help whenever possible.,\n        Do not rely on your own knowledge too much,\n        instead use the tools to answer queries.\n    ", metadata={}, model='gpt-4o-mini-2024-07-18', object='response', output=[], parallel_tool_calls=False, temperature=1.0, tool_choice='auto', tools=[FunctionTool(name='multiply', parameters={'properties': {'x': {'title': 'X', 'type': 'integer'}, 'y': {'title': 'Y', 'type': 'integer'}}, 'required': ['x', 'y'], 'title': 'multiply_args', 'type': 'object', 'additionalProperties': False}, strict=True, type='function', description='Multiply 2 numbers to provide the product')], top_p=1.0, max_output_tokens=None, previous_response_id=None, reasoning=Reasoning(effort=None, generate_summary=None), status='in_progress', text=ResponseTextConfig(format=ResponseFormatText(type='text')), truncation='disabled', usage=None, user=None, store=True), type='response.in_progress'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseOutputItemAddedEvent(item=ResponseOutputMessage(id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', content=[], role='assistant', status='in_progress', type='message'), output_index=0, type='response.output_item.added'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseContentPartAddedEvent(content_index=0, item_id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', output_index=0, part=ResponseOutputText(annotations=[], text='', type='output_text'), type='response.content_part.added'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='The', item_id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' product', item_id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' of', item_id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' ', item_id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='4', item_id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' and', item_id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' ', item_id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='100', item_id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' is', item_id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta=' ', item_id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='400', item_id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDeltaEvent(content_index=0, delta='.', item_id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', output_index=0, type='response.output_text.delta'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseTextDoneEvent(content_index=0, item_id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', output_index=0, text='The product of 4 and 100 is 400.', type='response.output_text.done'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseContentPartDoneEvent(content_index=0, item_id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', output_index=0, part=ResponseOutputText(annotations=[], text='The product of 4 and 100 is 400.', type='output_text'), type='response.content_part.done'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseOutputItemDoneEvent(item=ResponseOutputMessage(id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', content=[ResponseOutputText(annotations=[], text='The product of 4 and 100 is 400.', type='output_text')], role='assistant', status='completed', type='message'), output_index=0, type='response.output_item.done'), type='raw_response_event')
# RawResponsesStreamEvent(data=ResponseCompletedEvent(response=Response(id='resp_67f00138248881918da842ac4b343f96033b035ae1f324ea', created_at=1743782200.0, error=None, incomplete_details=None, instructions="\n        You're a helpful assistant who uses,\n        provided tools to help whenever possible.,\n        Do not rely on your own knowledge too much,\n        instead use the tools to answer queries.\n    ", metadata={}, model='gpt-4o-mini-2024-07-18', object='response', output=[ResponseOutputMessage(id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', content=[ResponseOutputText(annotations=[], text='The product of 4 and 100 is 400.', type='output_text')], role='assistant', status='completed', type='message')], parallel_tool_calls=False, temperature=1.0, tool_choice='auto', tools=[FunctionTool(name='multiply', parameters={'properties': {'x': {'title': 'X', 'type': 'integer'}, 'y': {'title': 'Y', 'type': 'integer'}}, 'required': ['x', 'y'], 'title': 'multiply_args', 'type': 'object', 'additionalProperties': False}, strict=True, type='function', description='Multiply 2 numbers to provide the product')], top_p=1.0, max_output_tokens=None, previous_response_id=None, reasoning=Reasoning(effort=None, generate_summary=None), status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text')), truncation='disabled', usage=ResponseUsage(input_tokens=134, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=14, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=148), user=None, store=True), type='response.completed'), type='raw_response_event')
# RunItemStreamEvent(name='message_output_created', item=MessageOutputItem(agent=Agent(name='Assistant', instructions="\n        You're a helpful assistant who uses,\n        provided tools to help whenever possible.,\n        Do not rely on your own knowledge too much,\n        instead use the tools to answer queries.\n    ", handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=False, truncation=None, max_tokens=None), tools=[FunctionTool(name='multiply', description='Multiply 2 numbers to provide the product', params_json_schema={'properties': {'x': {'title': 'X', 'type': 'integer'}, 'y': {'title': 'Y', 'type': 'integer'}}, 'required': ['x', 'y'], 'title': 'multiply_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x71e8678edbd0>, strict_json_schema=True)], mcp_servers=[], input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseOutputMessage(id='msg_67f00138a0688191b0da1aedc186e736033b035ae1f324ea', content=[ResponseOutputText(annotations=[], text='The product of 4 and 100 is 400.', type='output_text')], role='assistant', status='completed', type='message'), type='message_output_item'), type='run_item_stream_event')

# %% [markdown]
# ### Parsing Tool calling Events

# %%
from openai.types.responses import (
    ResponseFunctionCallArgumentsDeltaEvent,
    ResponseTextDeltaEvent
)

response = Runner.run_streamed(
    starting_agent=agent,
    input="Multiply 4 with 7"
)

async for event in response.stream_events():
    
    if event.type == 'raw_response_event':
        if isinstance(event.data, ResponseFunctionCallArgumentsDeltaEvent):
            # tool call
            print(event.data.delta, end="", flush=True)
        elif isinstance(event.data, ResponseTextDeltaEvent):
            # final answer
            print(event.data.delta, end="", flush=True)
    elif event.type == 'agent_updated_stream_event':
        # current agent
        print(f"> Current Agent: {event.new_agent.name}")
    elif event.type == 'run_item_stream_event':
        if event.name == 'tool_called':
            # this is complete collection of tool call after the tokens indicating
            # tool call are completely streamed out
            print()
            print(f"> Tool called: {event.item.raw_item.name}")
            print(f"> Tool args: {event.item.raw_item.arguments}")
        elif event.name == 'tool_output':
            print(f"> Tool Output: {event.item.raw_item['output']}")
# Out:
# > Current Agent: Assistant
# {"x":4,"y":7}
# > Tool called: multiply
# > Tool args: {"x":4,"y":7}
# > Tool Output: 28
# The product of 4 and 7 is 28.

# %% [markdown]
# ## Guardrails

# %%
from pydantic import BaseModel

# define structure for output guardrail
class GuardrailOutput(BaseModel):
    is_triggered: bool
    reasoning: str
    
# an agent that checks if user is asking about political opinions
politics_agent = Agent(
    name="Politics check",
    instructions="Check if the user is asking you about political opinions.",
    output_type=GuardrailOutput
)

# %%
query = "What do you think about BJP in India ?"

result = await Runner.run(starting_agent=politics_agent, input=query)
result
# Out:
# RunResult(input='What do you think about BJP in India ?', new_items=[MessageOutputItem(agent=Agent(name='Politics check', instructions='Check if the user is asking you about political opinions.', handoff_description=None, handoffs=[], model=None, model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=False, truncation=None, max_tokens=None), tools=[], mcp_servers=[], input_guardrails=[], output_guardrails=[], output_type=<class '__main__.GuardrailOutput'>, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseOutputMessage(id='msg_67f0013c7b6c8191b154d6ff08acfb03013c60bd13899484', content=[ResponseOutputText(annotations=[], text='{"is_triggered":true,"reasoning":"The user is asking for an opinion on a political party, BJP, in India, which falls under the category of political opinions."}', type='output_text')], role='assistant', status='completed', type='message'), type='message_output_item')], raw_responses=[ModelResponse(output=[ResponseOutputMessage(id='msg_67f0013c7b6c8191b154d6ff08acfb03013c60bd13899484', content=[ResponseOutputText(annotations=[], text='{"is_triggered":true,"reasoning":"The user is asking for an opinion on a political party, BJP, in India, which falls under the category of political opinions."}', type='output_text')], role='assistant', status='completed', type='message')], usage=Usage(requests=1, input_tokens=31, output_tokens=38, total_tokens=69), referenceable_id='resp_67f0013be2c48191bc1feb7b96496550013c60bd13899484')], final_output=GuardrailOutput(is_triggered=True, reasoning='The user is asking for an opinion on a political party, BJP, in India, which falls under the category of political opinions.'), input_guardrail_results=[], output_guardrail_results=[], _last_agent=Agent(name='Politics check', instructions='Check if the user is asking you about political opinions.', handoff_description=None, handoffs=[], model=None, model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=False, truncation=None, max_tokens=None), tools=[], mcp_servers=[], input_guardrails=[], output_guardrails=[], output_type=<class '__main__.GuardrailOutput'>, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True))

# %%
result.final_output
# Out:
# GuardrailOutput(is_triggered=True, reasoning='The user is asking for an opinion on a political party, BJP, in India, which falls under the category of political opinions.')

# %% [markdown]
# ### Integrating the guardrail with our agent
#
# For the Input Guardrail to work on the agent, we need to pass
# the logic to a single function
#
# * Input parameters include: `ctx` (Context), `agent`, `input`
# * Output must be a `GuardrailFunctionOutput` object

# %%
from agents import (
    GuardrailFunctionOutput,
    RunContextWrapper,
    input_guardrail
)

@input_guardrail
async def politics_guardrail(
    ctx: RunContextWrapper[None],
    agent: Agent,
    input: str
) -> GuardrailFunctionOutput:
    
    # run agent to check if guardrail is triggered
    response = await Runner.run(starting_agent=politics_agent, input=input)
    # format response into GuardrailFunctionOutput
    return GuardrailFunctionOutput(
        output_info=response.final_output,
        tripwire_triggered=response.final_output.is_triggered
    )

# %%
# Redefine agent with input guardrail
agent = Agent(
    name="Assistant",
    instructions="""
        You're a helpful assistant who uses,
        provided tools to help whenever possible.,
        Do not rely on your own knowledge too much,
        instead use the tools to answer queries.
    """,
    model=MODEL,
    tools=[multiply],
    input_guardrails=[politics_guardrail]
)

# %%
result = await Runner.run(
    starting_agent=agent,
    input="multiply 4 with 7"
)

result.final_output
# Out:
# 'The product of 4 and 7 is 28.'

# %%
result = await Runner.run(
    starting_agent=agent,
    input="What do you think about the BJP in India"
)

result.final_output
# Out:
# ---------------------------------------------------------------------------
# InputGuardrailTripwireTriggered           Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 result = await Runner.run(
#       2     starting_agent=agent,
#       3     input="What do you think about the BJP in India"
#       4 )
#       6 result.final_output
#
# File ~/Documents/coding/genai/openai-agents/venv/lib/python3.10/site-packages/agents/run.py:215, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config)
#     210 logger.debug(
#     211     f"Running agent {current_agent.name} (turn {current_turn})",
#     212 )
#     214 if current_turn == 1:
# --> 215     input_guardrail_results, turn_result = await asyncio.gather(
#     216         cls._run_input_guardrails(
#     217             starting_agent,
#     218             starting_agent.input_guardrails
#     219             + (run_config.input_guardrails or []),
#     220             copy.deepcopy(input),
#     221             context_wrapper,
#     222         ),
#     223         cls._run_single_turn(
#     224             agent=current_agent,
#     225             all_tools=all_tools,
#     226             original_input=original_input,
#     227             generated_items=generated_items,
#     228             hooks=hooks,
#     229             context_wrapper=context_wrapper,
#     230             run_config=run_config,
#     231             should_run_agent_start_hooks=should_run_agent_start_hooks,
#     232             tool_use_tracker=tool_use_tracker,
#     233         ),
#     234     )
#     235 else:
#     236     turn_result = await cls._run_single_turn(
#     237         agent=current_agent,
#     238         all_tools=all_tools,
#    (...)
#     245         tool_use_tracker=tool_use_tracker,
#     246     )
#
# File ~/Documents/coding/genai/openai-agents/venv/lib/python3.10/site-packages/agents/run.py:835, in Runner._run_input_guardrails(cls, agent, guardrails, input, context)
#     828         t.cancel()
#     829     _error_tracing.attach_error_to_current_span(
#     830         SpanError(
#     831             message="Guardrail tripwire triggered",
#     832             data={"guardrail": result.guardrail.get_name()},
#     833         )
#     834     )
# --> 835     raise InputGuardrailTripwireTriggered(result)
#     836 else:
#     837     guardrail_results.append(result)
#
# InputGuardrailTripwireTriggered: Guardrail InputGuardrail triggered tripwire

# %% [markdown]
# The Guardrail got triggered ! A `tripwire` is like a fail-safe for Guardrails.
#
# In some cases,
# when the guardrail is triggered, the system needs to **hard** stop. This is where tripwires can help

# %% [markdown]
# ## Conversational Agent
#
# We can use `.to_input_list()` on our return object to create a list of messages from the output, that can be used further.

# %%
result = await Runner.run(
    starting_agent=agent,
    input="Remember the number 42 please"
)

result.final_output
# Out:
# "I can't store information for future use, but I can remember details during our current chat! If you need to refer to the number 42 later in this conversation, feel free to ask!"

# %%
result.to_input_list()
# Out:
# [{'content': 'Remember the number 42 please', 'role': 'user'},
#  {'id': 'msg_67f0146aa6308191ae59d964ef0b6eca06c69f5e3b0906f3',
#   'content': [{'annotations': [],
#     'text': "I can't store information for future use, but I can remember details during our current chat! If you need to refer to the number 42 later in this conversation, feel free to ask!",
#     'type': 'output_text'}],
#   'role': 'assistant',
#   'status': 'completed',
#   'type': 'message'}]

# %%
result = await Runner.run(
    starting_agent=agent,
    input=result.to_input_list() + [
        {"role": "user", "content": "Multiply the last number with 6"}
    ]
)

result.final_output
# Out:
# 'The result of multiplying 42 by 6 is 252.'
